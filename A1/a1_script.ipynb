# %%
# Model source: https://huggingface.co/prompthero/openjourney

from diffusers import StableDiffusionPipeline
import torch
model_id = "prompthero/openjourney"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# prompt = "Surrealist depiction of a full-body unknown creature with undefined features floating within an ethereal whimsical space of mauve and silver tones. Silver swirls reminiscent of soldering are positioned around the piece. The scene should be foggy, unclear, not too smooth, and asymmetrical"
# prompt = "Organic forms inspired by the shapes of plant roots and mold. Muted cold colours, mainly mauve and silver. Use the space like a collage, being asymmetric and unexpected."
prompt = "Organic forms inspired by the movement of mold. Muted natural colours, mauve and light silver against a bright background with light rays. Superimpose shapes and be asymmetric and gruesome. No harsh lines or perfect shapes & circles"
image = pipe(prompt).images[0]
image.save("./prompt_img.jpg")
